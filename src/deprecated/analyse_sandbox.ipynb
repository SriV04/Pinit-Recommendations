# %% [markdown]
# # Pinit Recommendation Sandbox
# Interactive notebook to experiment with each stage of the local Pinit recommendation pipeline without Supabase.

# %% [markdown]
# ## Workflow Overview
# 1. Configure paths and helpers.
# 2. Load the canonical location inventory from CSVs.
# 3. Derive taxonomy + location tags (deterministic + reviews).
# 4. Build/synthesize user actions and compute taste profiles.
# 5. Generate recommendation scores + inspect outputs.
# 6. Persist artifacts for downstream experiments.

# %%
from pathlib import Path
import json
import pandas as pd

from config import PipelineConfig, PipelinePaths, ReviewTagConfig
from recommendation.tag_taxonomy import tag_dataframe
from recommendation.static_tagging import load_locations, load_reviews, build_location_tags
from recommendation.user_profiles import ensure_user_actions, build_user_tag_affinities
from recommendation.recommendation import build_recommendations

# %% [markdown]
# ### Configure paths + output folders

# %%
DATA_DIR = Path("../../data/raw")
CITY_NAME = "london"
OUTPUT_DIR = Path("../../output/pinit_notebook")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

paths = PipelinePaths(data_dir=DATA_DIR, city_name=CITY_NAME, output_dir=OUTPUT_DIR)
review_cfg = ReviewTagConfig(min_unique_authors=2, min_mentions=3)
config = PipelineConfig(paths=paths, review_tagging=review_cfg, top_k_per_user=25)
config
# Out:
# PipelineConfig(paths=PipelinePaths(data_dir=PosixPath('../../data/raw'), city_name='london', output_dir=PosixPath('../../output/pinit_notebook'), user_actions_csv=None, user_friends_csv=None, bubble_locations_csv=None), review_tagging=ReviewTagConfig(min_unique_authors=2, min_mentions=3, english_only=True, score_floor=20.0, score_cap=100.0), recommendation_weights=RecommendationWeights(taste=0.5, trend_app=0.15, hidden_gems=0.2, quality=0.15, friend=0.0, bubble=0.0), synthetic_users=True, top_k_per_user=25)

# %% [markdown]
# ## 1. Load canonical location inventory

# %%
locations = load_locations(paths)
print(f"Loaded {len(locations):,} locations")
locations.head()
# Out:
# Loaded 1,608 locations
#                       place_id                         name  \
# 0  ChIJNSXdCgBT30cRJCJlCeqYZq4              Piccolo's Pizza
# 1  ChIJB7xIORNS30cRSpYmpEaUvvM    Miller & Carter Sevenoaks
# 2  ChIJZa00u2xS30cRYBr8E5bIYdM                       Sun On
# 3  ChIJTW54IChT30cR_lIlYS9uZZI              Linden Catering
# 4  ChIJ7_uwBeRT30cRt_w4ylhWfF4  Kanosh Lebanese Street Food
#
#                                                types  rating  \
# 0    establishment,food,point_of_interest,restaurant     NaN
# 1    establishment,food,point_of_interest,restaurant     4.5
# 2  establishment,food,meal_takeaway,point_of_inte...     3.6
# 3    establishment,food,point_of_interest,restaurant     NaN
# 4  establishment,food,meal_takeaway,point_of_inte...     5.0
#
#    user_ratings_total  price_level        lat       lon  \
# 0                 0.0          NaN  51.283470  0.169840
# 1              1895.0          2.0  51.283125  0.170598
# 2                40.0          NaN  51.284885  0.169742
# 3                 0.0          NaN  51.289080  0.168472
# 4                 4.0          NaN  51.289309  0.168325
#
#                                  vicinity     business_status  ...  \
# 0                    Riverhead, Sevenoaks         OPERATIONAL  ...
# 1      Amherst Hill, Riverhead, Sevenoaks         OPERATIONAL  ...
# 2      27 London Rd, Riverhead, Sevenoaks         OPERATIONAL  ...
# 3  Riverpoint house, London Rd, Sevenoaks         OPERATIONAL  ...
# 4                    London Rd, Sevenoaks  CLOSED_TEMPORARILY  ...
#
#   price_bucket log_reviews popularity_score expected_popularity  \
# 0      unknown    0.000000         0.000000            4.028667
# 1          mid    7.547502         0.842022            5.480125
# 2      unknown    3.713572         0.414297            4.329621
# 3      unknown    0.000000         0.000000            2.186523
# 4      unknown    1.609438         0.179554            4.053022
#
#   residual_popularity quality_score hidden_gem_score    hidden_gem_source  \
# 0           -4.028667      0.811178         0.734039  popularity_residual
# 1            2.067377      0.875000         0.000000  popularity_residual
# 2           -0.616049      0.650000         0.112247  popularity_residual
# 3           -2.186523      0.811178         0.398393  popularity_residual
# 4           -2.443584      1.000000         0.445231  popularity_residual
#
#   expected_rating  hype_residual
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN
#
# [5 rows x 40 columns]

# %%
locations[['location_id','name','cuisine_primary','price_level','rating','user_ratings_total','is_open_late','is_open_early']].head(10)
# Out:
#    location_id                           name cuisine_primary  price_level  \
# 0            1                Piccolo's Pizza         italian          NaN
# 1            2      Miller & Carter Sevenoaks         unknown          2.0
# 2            3                         Sun On          indian          NaN
# 3            4                Linden Catering         unknown          NaN
# 4            5    Kanosh Lebanese Street Food  middle_eastern          NaN
# 5            6           E K B GOURMET BURGER        american          NaN
# 6            7                 M&S Food To Go         unknown          2.0
# 7            8                       The Bell             pub          2.0
# 8            9             Trattoria Da Carlo         italian          NaN
# 9           10  Zen Garden Chinese Restaurant         chinese          2.0
#
#    rating  user_ratings_total  is_open_late  is_open_early
# 0     NaN                 0.0         False          False
# 1     4.5              1895.0          True          False
# 2     3.6                40.0         False          False
# 3     NaN                 0.0         False          False
# 4     5.0                 4.0         False          False
# 5     3.0                 3.0          True          False
# 6     2.8                98.0         False           True
# 7     4.4               877.0          True          False
# 8     4.5                69.0         False          False
# 9     4.2               260.0         False          False

# %%
place_to_location = locations.set_index('google_place_id')['location_id'].to_dict()

reviews = load_reviews(paths, place_to_location)
print(f"Loaded {len(reviews):,} reviews")

place_to_location
# Out:
# Loaded 7,240 reviews
# {'ChIJNSXdCgBT30cRJCJlCeqYZq4': 1,
#  'ChIJB7xIORNS30cRSpYmpEaUvvM': 2,
#  'ChIJZa00u2xS30cRYBr8E5bIYdM': 3,
#  'ChIJTW54IChT30cR_lIlYS9uZZI': 4,
#  'ChIJ7_uwBeRT30cRt_w4ylhWfF4': 5,
#  'ChIJHbX02-1T30cRDO1efNmH4nU': 6,
#  'ChIJAcqe0zzZdUgR3pDe79_xkh0': 7,
#  'ChIJ_bgO35PgdUgR3QVkvi-fwnc': 8,
#  'ChIJMYLkfI7gdUgRFesJVMX5PPo': 9,
#  'ChIJcz21cuXgdUgROfpWnFBuIoA': 10,
#  'ChIJ1R6NmV__dUgROJgVsZpFaR4': 11,
#  'ChIJj-4uTIxN30cRNFTyf69vF2c': 12,
#  'ChIJZ32W9z0edkgR9h7CjmWO3Gc': 904,
#  'ChIJAWhxk5wfdkgRgdiLvFMI5F0': 905,
#  'ChIJsQDW16wfdkgRilME9ikqsDU': 906,
#  'ChIJR60x0h4edkgRYo1I3z1HcyI': 907,
#  'ChIJD33EHqKg2EcRU-VE_i61h5U': 908,
#  'ChIJs8k8vKGg2EcRSqsMJvtnO1M': 909,
#  'ChIJz3EuvAIedkgRaKKg_uf2qHM': 910,
#  'ChIJk28tvAIedkgRBr5Kci83U2w': 911,
#  'ChIJ4fIqHR0edkgRWx3OiIFdIlw': 912,
#  'ChIJ72iwYQIedkgRC0ttHxFdUOo': 913,
#  'ChIJg6pM_aeg2EcRZa_F3-aySzw': 914,
#  'ChIJD33EHqKg2EcRAyehohi4bv4': 915,
#  'ChIJPW_RJqig2EcRbyyOtgWxcuM': 916,
#  'ChIJ3XQghLeg2EcR80SRpse9tJs': 917,
#  'ChIJQ3g5mpGg2EcRVvyhu3WourA': 918,
#  'ChIJjwWII7ig2EcR-lbRZmwk2ko': 919,
#  'ChIJ_1zO9reg2EcR2oGHi76iqbs': 920,
#  'ChIJazUSjreg2EcRmbvW5TiJkbY': 921,
#  'ChIJjwWII7ig2EcRSrKcKmveaVU': 922,
#  'ChIJD2KaKbig2EcRPWtiT7M8M-Q': 923,
#  'ChIJSyiEtvyh2EcR4XZd8HWd8g4': 924,
#  'ChIJ67Fhykih2EcRfiJxhsrUBbE': 925,
#  'ChIJ2-eYzMOh2EcR6fHn_IM7AHo': 926,
#  'ChIJ-UsQz8Cg2EcRlPywGT-8nWI': 927,
#  'ChIJYxaS4jyh2EcROZEjfH4Mk6U': 928,
#  'ChIJW5kkwtyh2EcRk8ebwDKGIzQ': 929,
#  'ChIJsbCwLaig2EcRVJBKrkdIsHs': 930,
#  'ChIJsTIHcACh2EcRocdefowPdPk': 931,
#  'ChIJ3wOY0U2h2EcRsNbqQKOPW98': 932,
#  'ChIJqRdCwy-h2EcRIqDHv6AmMEg': 933,
#  'ChIJ83Utt6eg2EcR9M_HlkhpmqE': 934,
#  'ChIJRXUyGaig2EcRwRS5ZEOEd_w': 935,
#  'ChIJ94MFMQIfdkgRHcqfCHt0fb8': 936,
#  'ChIJg6pM_aeg2EcRXo6sTy-NsBY': 937,
#  'ChIJVVUKIqig2EcRij0azkoNtV0': 938,
#  'ChIJZyc2Iaig2EcRnU-I25bcxNU': 939,
#  'ChIJVcQTM6ig2EcRZkx1WVUh9-k': 940,
#  'ChIJqwVLVN6h2EcRTV1robBB-sw': 941,
#  'ChIJRcgvk8Wh2EcRcIuCHxFWkkc': 942,
#  'ChIJbRPWYAIedkgRC5_nIneE03A': 943,
#  'ChIJN76Dtqmg2EcRsBUotqNDVQY': 944,
#  'ChIJoYRwc0AfdkgRNxkg-Lkngts': 945,
#  'ChIJy8jokQIedkgRrX3JoFNMO_g': 946,
#  'ChIJM8FvDOAfdkgR5pf9sdptRcA': 947,
#  'ChIJXfbGgwIedkgRkAk7ITvR3cs': 948,
#  'ChIJZ3VVLaig2EcRKGwy-n3xS6k': 949,
#  'ChIJtytVs4yh2EcRjlMlLnb5HEo': 950,
#  'ChIJRTh9v_UfdkgRZZCg2dhKvCM': 951,
#  'ChIJYXsDu0kfdkgRW0eNXRx1z78': 952,
#  'ChIJqTQXEQAfdkgR6uV3HDWDBWQ': 953,
#  'ChIJXVUHYQIedkgRMIoDpXwFUAw': 954,
#  'ChIJhfDezP6g2EcRD1B3S4ZOo-U': 955,
#  'ChIJGUZfuc-g2EcRrRXzDZWL9Lw': 956,
#  'ChIJp9tAKu-g2EcRmfPXIfwfEsU': 957,
#  'ChIJYUHJ-d6g2EcRF39soKT4MiA': 958,
#  'ChIJJ9caOOmg2EcRPv0PzeXh1wA': 959,
#  'ChIJ9UL4Q9Cg2EcRFk1M-DQuXsc': 960,
#  'ChIJjUwAv8-g2EcR8QvvVBwqMyg': 961,
#  'ChIJ_TxE9tCg2EcRtehN7Nez71U': 962,
#  'ChIJ1RLUKdCg2EcR1H1qhZO9y3I': 963,
#  'ChIJ38LygeGg2EcRJ9HwsXfzTDU': 964,
#  'ChIJqzOR4zmn2EcRz85eoqhG-dU': 965,
#  'ChIJk8ZHrs-g2EcRVyMQHVQqfiQ': 966,
#  'ChIJIbkwgOGg2EcRTsC_bDU94zg': 967,
#  'ChIJKVZyuM-g2EcRmmL8C3RlY-c': 968,
#  'ChIJdY9KKNCg2EcRsnG-SnxfKv4': 969,
#  'ChIJnUP4Q9Cg2EcRXQrE7LoOZDo': 970,
#  'ChIJbcpafUun2EcRqYoJG5NQ15I': 971,
#  'ChIJ7T5B2uWg2EcRGTKT72iIk8U': 972,
#  'ChIJC9O_CgCh2EcRLE6mr_RW4Qc': 973,
#  'ChIJV8BH-uWg2EcRIO53CN42QAo': 974,
#  'ChIJX6zY5OWg2EcRfg1WaBkYVlY': 975,
#  'ChIJ2U5X5WWh2EcRYpS8GkAxeKs': 976,
#  'ChIJey982uWg2EcRvTbek1CVWwI': 977,
#  'ChIJMZdY1eOg2EcReAZ36vFpouA': 978,
#  'ChIJeQEex8-g2EcR5ESApeHGwH8': 979,
#  'ChIJvZvGI8yh2EcRBrd1sAKku5M': 980,
#  'ChIJnc3N6Leh2EcRDxwAMCdjjB0': 981,
#  'ChIJt5eS4eOg2EcR4_xnAOxV2oc': 982,
#  'ChIJwZnNN9-h2EcRSb9RoUBu3vg': 983,
#  'ChIJp521auSh2EcRXsknI1f-STY': 984,
#  'ChIJ2_5Rql6h2EcRkdznpP8nzYA': 985,
#  'ChIJEzfPIBWh2EcRFon1nvmDGB4': 986,
#  'ChIJFcHHbAmh2EcR-BBYlww-CvA': 987,
#  'ChIJTa917Jqh2EcR62oRpZuyHxM': 988,
#  'ChIJP2PtcPuh2EcRDcmSqBtgX-A': 989,
#  'ChIJWzInWCyh2EcRFS8-GOxMAU8': 990,
#  'ChIJZ-V0jHih2EcRHTmTdn25p1M': 991,
#  'ChIJWVdWGeKg2EcRXaKp5kJZtG0': 992,
#  'ChIJcebM4EWh2EcRPVrAZCGp9u8': 993,
#  'ChIJf30bu5eh2EcReCewqfe784k': 994,
#  'ChIJzfxv--Gg2EcROUW8ZV0fVM4': 995,
#  'ChIJ7ZJDyS6h2EcRo8qYNFuTzxo': 996,
#  'ChIJRz_s-i6h2EcRvmveyTJgeDo': 997,
#  'ChIJaSJUbCmh2EcRVpkZHovu-cU': 998,
#  'ChIJj_5O8mmh2EcRfhFr_tLD8CU': 999,
#  'ChIJW2yBTTCh2EcR7KCUkwbIW7k': 1000,
#  ...}

# %% [markdown]
# ## 2. Build taxonomy + location tags

# %%
tags_df = tag_dataframe()
reviews_df = load_reviews(paths, locations.set_index('google_place_id')['location_id'].to_dict())
location_tags = build_location_tags(locations, reviews_df, config.review_tagging)
print(f"Tags defined: {len(tags_df)} | Tagged pairs: {len(location_tags):,}")
# Out:
# Tags defined: 47 | Tagged pairs: 6,465

# %%
tags_df
# write tags_df into a csv file
tags_df.to_csv(OUTPUT_DIR / "tags.csv", index=False)

# %%
location_tags_with_names = location_tags.merge(locations[["location_id", "name"]], on="location_id")
location_tags_with_names
# Out:
#       location_id         tag_text      score            source  \
# 0               1          italian  92.000000  cuisine_detected
# 1               1       restaurant  75.000000      google_types
# 2               2       restaurant  75.000000      google_types
# 3               2        open_late  70.000000     opening_hours
# 4               2      sunday_open  65.000000     opening_hours
# ...           ...              ...        ...               ...
# 6460         1595  family_friendly  47.465307           reviews
# 6461         1598  family_friendly  47.465307           reviews
# 6462         1600            quiet  47.465307           reviews
# 6463         1604           lively  47.465307           reviews
# 6464         1605            quiet  47.465307           reviews
#
#                                   metadata  tag_id  \
# 0             {"field": "cuisine_primary"}       1
# 1                   {"type": "restaurant"}      44
# 2                   {"type": "restaurant"}      44
# 3                                       {}      38
# 4                                       {}      40
# ...                                    ...     ...
# 6460  {"mentions": 2, "unique_authors": 2}      28
# 6461  {"mentions": 2, "unique_authors": 2}      28
# 6462  {"mentions": 2, "unique_authors": 2}      24
# 6463  {"mentions": 2, "unique_authors": 2}      23
# 6464  {"mentions": 2, "unique_authors": 2}      24
#
#                               name
# 0                  Piccolo's Pizza
# 1                  Piccolo's Pizza
# 2        Miller & Carter Sevenoaks
# 3        Miller & Carter Sevenoaks
# 4        Miller & Carter Sevenoaks
# ...                            ...
# 6460                         Rootz
# 6461  Sathi Restaurant Chorleywood
# 6462          The Bank Chorleywood
# 6463   Nonno's Pizza (Chorleywood)
# 6464                   INDIA RASOI
#
# [6465 rows x 7 columns]

# %% [markdown]
# ## 3. Build/simulate user actions + taste profiles

# %%
user_actions, synthetic = ensure_user_actions(paths, locations, location_tags, allow_synthetic=config.synthetic_users)
print(f"Loaded {len(user_actions)} user actions | synthetic={synthetic}")
user_actions
# Out:
# Loaded 36 user actions | synthetic=True
#             user_id                     place_id       action  \
# 0   demo_date_night  ChIJNSXdCgBT30cRJCJlCeqYZq4         like
# 1   demo_date_night  ChIJMYLkfI7gdUgRFesJVMX5PPo  detail_view
# 2   demo_date_night  ChIJj-4uTIxN30cRNFTyf69vF2c         like
# 3   demo_date_night  ChIJi1GLWQXhdUgRdZKBQ0UZ4oQ  detail_view
# 4   demo_date_night  ChIJy0c3bIXYdUgRojTzdhXE09Y         like
# 5   demo_date_night  ChIJDziemhAHdkgRPgRx1c7zC-8         save
# 6   demo_date_night  ChIJleBWrQULdkgRstOAcogkSFc         like
# 7   demo_date_night  ChIJ0X6uEBELdkgRlWlZh5uIRX8  detail_view
# 8   demo_date_night  ChIJ5ekJCS5xdkgRUbU1cErJ11g         like
# 9   demo_date_night  ChIJUyVgzv1zdkgR08_8R-kLGJ0         like
# 10  demo_date_night  ChIJ90JoW1APdkgRzq-H54TemLs         save
# 11  demo_date_night  ChIJXx_bCSxxdkgRSnY2HoSD7pA         save
# 12       demo_vegan  ChIJ1R6NmV__dUgROJgVsZpFaR4  detail_view
# 13       demo_vegan  ChIJ0ZC0oit2dkgRv9sDyGigQ1Y         like
# 14       demo_vegan  ChIJ2V0PyugKdkgRdgvkKB8LRo0         save
# 15       demo_vegan  ChIJc0XoTEIBdkgRKb6vL3xEITA  detail_view
# 16       demo_vegan  ChIJ8z0xSzICdkgRy9McWT7TrGU         like
# 17       demo_vegan  ChIJX3CsvKqp2EcRh88XtfxhJ9A         like
# 18       demo_vegan  ChIJWQ5ZV0AOdkgRzzzdnQyF2xY         save
# 19       demo_vegan  ChIJ0ZWAFyBydkgR9Mgjhv8MmHs         like
# 20       demo_vegan  ChIJcZcPQuWv2EcRklptJcVc_pU         like
# 21       demo_vegan  ChIJJchWTRoOdkgRVDtnHVLMDZs         save
# 22       demo_vegan  ChIJcxaCi-6j2EcREhbf91J-XQc         save
# 23       demo_vegan  ChIJQWDBwI-j2EcRTzmqt4wdxr0         save
# 24  demo_group_hang  ChIJP0Eb191rdkgR6OV7kuxieAs         save
# 25  demo_group_hang  ChIJ__9P-60UdkgRLtcGcg_nzPo         save
# 26  demo_group_hang  ChIJq_MZ418VdkgRrM-edcJyaOc         like
# 27  demo_group_hang  ChIJ-Wiyo4kUdkgR1yUnbMcrq1g  detail_view
# 28  demo_group_hang  ChIJgxNdyacVdkgR5UO49qWe-Qo         like
# 29  demo_group_hang  ChIJr4-9oVUXdkgRTkh56qN3GSM  detail_view
# 30  demo_group_hang  ChIJgcVKYNwWdkgRRf2ubYz4-FI  detail_view
# 31  demo_group_hang  ChIJB4nhUk0XdkgRFf5Py4VoNPU         save
# 32  demo_group_hang  ChIJTUXLBCsZdkgRBLLFnObk7UE         like
# 33  demo_group_hang  ChIJswoEZC0ZdkgRDjdHKhi8UDM         save
# 34  demo_group_hang  ChIJrfRz6UcZdkgRYrSntflQri4         save
# 35  demo_group_hang  ChIJgxqROhQedkgR80OcSrJ0dvI         like
#
#                           created_at
# 0   2025-10-22T14:28:28.198186+00:00
# 1   2025-11-10T14:28:28.199197+00:00
# 2   2025-12-01T14:28:28.199236+00:00
# 3   2025-12-11T14:28:28.199269+00:00
# 4   2025-10-16T14:28:28.199306+00:00
# 5   2025-10-10T14:28:28.199340+00:00
# 6   2025-11-04T14:28:28.199370+00:00
# 7   2025-11-16T14:28:28.199399+00:00
# 8   2025-11-13T14:28:28.199428+00:00
# 9   2025-10-06T14:28:28.199456+00:00
# 10  2025-12-11T14:28:28.199484+00:00
# 11  2025-10-31T14:28:28.199512+00:00
# 12  2025-11-25T14:28:28.200139+00:00
# 13  2025-10-24T14:28:28.200171+00:00
# 14  2025-12-13T14:28:28.200198+00:00
# 15  2025-09-23T14:28:28.200224+00:00
# 16  2025-10-12T14:28:28.200249+00:00
# 17  2025-12-02T14:28:28.200275+00:00
# 18  2025-10-31T14:28:28.200299+00:00
# 19  2025-12-06T14:28:28.200322+00:00
# 20  2025-11-17T14:28:28.200346+00:00
# 21  2025-09-23T14:28:28.200369+00:00
# 22  2025-12-13T14:28:28.200393+00:00
# 23  2025-11-07T14:28:28.200416+00:00
# 24  2025-10-19T14:28:28.201068+00:00
# 25  2025-11-07T14:28:28.201146+00:00
# 26  2025-09-26T14:28:28.201200+00:00
# 27  2025-11-10T14:28:28.201234+00:00
# 28  2025-12-11T14:28:28.201264+00:00
# 29  2025-11-21T14:28:28.201292+00:00
# 30  2025-10-05T14:28:28.201320+00:00
# 31  2025-11-15T14:28:28.201347+00:00
# 32  2025-10-23T14:28:28.201373+00:00
# 33  2025-12-07T14:28:28.201399+00:00
# 34  2025-10-09T14:28:28.201425+00:00
# 35  2025-10-10T14:28:28.201451+00:00

# %%
user_tags, user_history = build_user_tag_affinities(user_actions, location_tags, locations)
print(f"Computed {len(user_tags)} user-tag affinities across {user_tags['user_id'].nunique()} users")
user_tags.head(10)
# Out:
# Computed 39 user-tag affinities across 3 users
# /Users/sriharshavitta/Projects/pinit-recommendations/src/pinit/user_profiles.py:156: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   normalized = agg.groupby("user_id", group_keys=False).apply(_normalize)
#            user_id  tag_id     tag_text       score  \
# 0  demo_date_night       1      italian  100.000000
# 1  demo_date_night      44   restaurant   81.521739
# 2  demo_date_night      47     takeaway   79.523405
# 3  demo_date_night      40  sunday_open   66.165839
# 4  demo_date_night      38    open_late   57.568438
# 5  demo_date_night      46          bar    8.309101
# 6  demo_date_night      41  great_value    7.600534
# 7  demo_date_night      39   open_early    6.650468
# 8  demo_group_hang      44   restaurant  100.000000
# 9  demo_group_hang      40  sunday_open   83.138164
#
#                              metadata
# 0    {"raw_score": 6.166226182463444}
# 1    {"raw_score": 5.026814822660416}
# 2    {"raw_score": 4.903592989468822}
# 3      {"raw_score": 4.0799352855448}
# 4   {"raw_score": 3.5498001049651977}
# 5   {"raw_score": 0.5123579809348315}
# 6  {"raw_score": 0.46866614826631425}
# 7  {"raw_score": 0.41008287973302493}
# 8    {"raw_score": 5.183389863654495}
# 9    {"raw_score": 4.309375161226154}

# %% [markdown]
# ## 4. Generate recommendation scores

# %%
recs = build_recommendations(locations, user_tags, location_tags, user_history, user_actions, config)
print(f"Generated {len(recs)} rec rows")
# Out:
# Generated 75 rec rows

# %%
def show_user_recs(user_id, n=10):
    subset = recs[recs['user_id'] == user_id].merge(
        locations[['location_id','name','vicinity','cuisine_primary','rating','user_ratings_total']],
        on='location_id', how='left'
    ).head(n)
    return subset[['rank','score','name','cuisine_primary','rating','user_ratings_total','reason']]

unique_users = recs['user_id'].unique().tolist()
unique_users[:3], len(unique_users)
# Out:
# (['demo_date_night', 'demo_group_hang', 'demo_vegan'], 3)

# %%
# Example: inspect top recommendations for the first user
if len(recs):
    example_user = recs['user_id'].iloc[0]
show_user_recs(example_user, n=10)
# Out:
#    rank     score                                    name cuisine_primary  \
# 0     1  2.041038             Nonno's Pizza (Chorleywood)         italian
# 1     2  2.038603               Domino's Pizza - Chigwell         italian
# 2     3  2.024309                Just Pizza Rickmansworth         italian
# 3     4  2.024218                             Pizza Go Go         italian
# 4     5  2.021643                  Pizza King Kebab House         italian
# 5     6  2.020989                              Mascalzone         italian
# 6     7  2.019286  County Fried Chicken & pizza & Burgers         italian
# 7     8  2.017219              Domino's Pizza - Brentwood         italian
# 8     9  2.016788                              Tops Pizza         italian
# 9    10  2.014908                 Farmhouse pizza Edgware         italian
#
#    rating  user_ratings_total  \
# 0     4.5               392.0
# 1     4.3                57.0
# 2     4.0                 1.0
# 3     4.1                96.0
# 4     3.9               494.0
# 5     4.3              1194.0
# 6     4.0               102.0
# 7     4.0                96.0
# 8     4.0               295.0
# 9     3.9               330.0
#
#                                               reason
# 0  {"taste_tags": [{"tag": "italian", "score": 0....
# 1  {"taste_tags": [{"tag": "italian", "score": 0....
# 2  {"taste_tags": [{"tag": "italian", "score": 0....
# 3  {"taste_tags": [{"tag": "italian", "score": 0....
# 4  {"taste_tags": [{"tag": "italian", "score": 0....
# 5  {"taste_tags": [{"tag": "italian", "score": 0....
# 6  {"taste_tags": [{"tag": "italian", "score": 0....
# 7  {"taste_tags": [{"tag": "italian", "score": 0....
# 8  {"taste_tags": [{"tag": "italian", "score": 0....
# 9  {"taste_tags": [{"tag": "italian", "score": 0....

# %% [markdown]
# ## 5. Persist notebook artifacts

# %%
# locations.to_csv(OUTPUT_DIR / 'locations.csv', index=False)
# location_tags.to_csv(OUTPUT_DIR / 'location_tags.csv', index=False)
# user_tags.to_csv(OUTPUT_DIR / 'user_tag_affinities.csv', index=False)
# recs.to_csv(OUTPUT_DIR / 'user_recommendations.csv', index=False)
# metadata = {
#     'city': CITY_NAME,
#     'n_locations': int(len(locations)),
#     'n_tags': int(len(tags_df)),
#     'n_location_tags': int(len(location_tags)),
#     'n_users': int(user_tags['user_id'].nunique()) if not user_tags.empty else 0,
#     'n_recommendations': int(len(recs)),
#     'synthetic_user_actions': bool(synthetic),
# }
# (OUTPUT_DIR / 'metadata.json').write_text(json.dumps(metadata, indent=2))
# metadata

# %% [markdown]
# ## Processing location_tags

# %%
# Choose Tags that are not in supabase
new_tags = tags_df[tags_df['supabase_id'].isnull()]   
new_tags.drop(columns=['tag_id', 'supabase_id', 'slug'], inplace=True)
new_tags = new_tags[['text', 'prompt_description', 'tag_type', 'color']]
new_tags.rename(columns={'color': 'colour'}, inplace=True)
new_tags
# Out:
# /var/folders/w5/q3g22k8d1_72830gw6496kz00000gn/T/ipykernel_19293/3551327770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_tags.drop(columns=['tag_id', 'supabase_id', 'slug'], inplace=True)
#                    text                              prompt_description  \
# 9               british      Modern British kitchens and proper roasts.
# 10                  pub   True pub fare with pints and Sunday sessions.
# 11               bakery          Bakeries, patisseries and pastry labs.
# 13              seafood  Raw bars, shellfish shacks and seafood grills.
# 15     vegan_vegetarian    Veggie-first kitchens and plant-based menus.
# 16  vegetarian_friendly          Menus with strong vegetarian sections.
# 17       vegan_friendly     Vegan-friendly options beyond token salads.
# 18       halal_friendly                        Halal-friendly kitchens.
# 19  gluten_free_options       Staff that knows their gluten-free swaps.
# 26               formal             White tablecloths or tasting menus.
# 28           date_night                            Romantic nights out.
# 31           group_hang       Space for friend groups and celebrations.
# 32     business_meeting          Laptop-friendly or client-ready rooms.
# 33        solo_friendly            Bar seats or counter dining for one.
# 34            cocktails          Serious cocktails or signature serves.
# 36           craft_beer                  Rotating taps and local brews.
# 37            open_late                  Kitchen keeps going past 11pm.
# 38           open_early                             Serving before 8am.
# 39          sunday_open                                Open on Sundays.
# 40          great_value                          Serious bang for buck.
# 41               pricey                      Splurge-worthy but spendy.
# 43           restaurant                       Full-service restaurants.
# 46             takeaway                           Grab-and-go friendly.
#
#     tag_type   colour
# 9    CUISINE  #F94144
# 10   CUISINE  #F94144
# 11   CUISINE  #F94144
# 13   CUISINE  #F94144
# 15   CUISINE  #F94144
# 16   DIETARY  #90BE6D
# 17   DIETARY  #90BE6D
# 18   DIETARY  #90BE6D
# 19   DIETARY  #90BE6D
# 26      VIBE  #577590
# 28  OCCASION  #F9C74F
# 31  OCCASION  #F9C74F
# 32  OCCASION  #F9C74F
# 33  OCCASION  #F9C74F
# 34    DRINKS  #277DA1
# 36    DRINKS  #277DA1
# 37  SCHEDULE  #F3722C
# 38  SCHEDULE  #F3722C
# 39  SCHEDULE  #F3722C
# 40     VALUE  #8338EC
# 41     VALUE  #8338EC
# 43  CATEGORY  #4D908E
# 46  CATEGORY  #4D908E

# %%
new_tags.to_csv(OUTPUT_DIR / "new_tags.csv", index=False)

# %% [markdown]
# ## Supabase setup

# %%
import supabase_config as sc
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Initialize Supabase service
service = sc.get_supabase_service()

# Test connection
print("Testing connection...")
if service.test_connection():
    print("✓ Connected to Supabase")
else:
    print("✗ Connection failed")

# Get all tags from tag_taxonomy
tags_from_db = service.get_all_tags()
print(f"✓ Loaded {len(tags_from_db)} tags from tag_taxonomy")

# Create mapping from tag text to UUID
tag_text_to_uuid = {tag['text']: tag['tag_id'] for tag in tags_from_db}
print(f"✓ Created tag mapping with {len(tag_text_to_uuid)} entries")

# Show sample
if tags_from_db:
    sample = tags_from_db[0]
    print(f"\nSample tag: {sample['text']} -> {sample['tag_id']}")
# Out:
# Testing connection...
# ✓ Connected to Supabase
# ✓ Loaded 104 tags from tag_taxonomy
# ✓ Created tag mapping with 104 entries
#
# Sample tag: casual -> 7f789b3e-ae55-4ac1-83fb-5ba3c785d793

# %% [markdown]
# ## Format location_tags for Supabase upload

# %%
# Load location_tags from the pipeline (already created above)
print(f"Original location_tags shape: {location_tags.shape}")
print(f"Columns: {location_tags.columns.tolist()}")

# Inspect first few rows to understand structure
print("\nFirst few rows:")
print(location_tags.head())

# Create a copy for Supabase formatting
location_tags_supabase = location_tags.copy()

# Identify the tag column - it might be 'tag_text', 'tag', or similar
tag_column = None
for col in ['tag_text', 'tag', 'text']:
    if col in location_tags_supabase.columns:
        tag_column = col
        break

if tag_column is None:
    raise ValueError(f"Could not find tag column in: {location_tags_supabase.columns.tolist()}")

print(f"\nUsing '{tag_column}' as the tag identifier column")

# Map the tag text to UUID from Supabase
location_tags_supabase['tag_id'] = location_tags_supabase[tag_column].map(tag_text_to_uuid)

# Check for unmapped tags
unmapped = location_tags_supabase[location_tags_supabase['tag_id'].isnull()]
if len(unmapped) > 0:
    print(f"\n⚠ Warning: {len(unmapped)} location_tags have unmapped tags:")
    print(f"Unmapped tags: {sorted(unmapped[tag_column].unique()[:10])}")
else:
    print("✓ All tags successfully mapped to UUIDs")

# Remove rows with unmapped tags
location_tags_supabase = location_tags_supabase[location_tags_supabase['tag_id'].notna()]

# Format according to Supabase schema:
# location_id, tag_id (uuid), score, source, metadata

# Rename confidence column to score if it exists
if 'confidence' in location_tags_supabase.columns:
    location_tags_supabase = location_tags_supabase.rename(columns={'confidence': 'score'})
elif 'score' not in location_tags_supabase.columns:
    # If no score column, set default
    location_tags_supabase['score'] = 1.0

# Add source column (indicates whether tag came from rules or reviews)
if 'source' not in location_tags_supabase.columns:
    location_tags_supabase['source'] = 'pipeline'

# Get tag_type from tags_df if available
tag_type_map = tags_df.set_index('text')['tag_type'].to_dict() if 'text' in tags_df.columns else {}

# Create metadata as JSON (can include original tag text for reference)
location_tags_supabase['metadata'] = location_tags_supabase.apply(
    lambda row: {
        'original_tag': row[tag_column], 
        'tag_type': tag_type_map.get(row[tag_column], 'unknown')
    },
    axis=1
)

# Select final columns for Supabase
final_columns = ['location_id', 'tag_id', 'score', 'source', 'metadata']
location_tags_final = location_tags_supabase[final_columns].copy()

# Convert metadata dict to JSON string for CSV export
location_tags_final['metadata'] = location_tags_final['metadata'].apply(json.dumps)

print(f"\nFinal location_tags shape: {location_tags_final.shape}")
print(f"Columns: {location_tags_final.columns.tolist()}")
print(f"\nSample rows:")
location_tags_final.head()
# Out:
# Original location_tags shape: (6465, 6)
# Columns: ['location_id', 'tag_text', 'score', 'source', 'metadata', 'tag_id']
#
# First few rows:
#    location_id     tag_text  score            source  \
# 0            1      italian   92.0  cuisine_detected
# 1            1   restaurant   75.0      google_types
# 2            2   restaurant   75.0      google_types
# 3            2    open_late   70.0     opening_hours
# 4            2  sunday_open   65.0     opening_hours
#
#                        metadata  tag_id
# 0  {"field": "cuisine_primary"}       1
# 1        {"type": "restaurant"}      44
# 2        {"type": "restaurant"}      44
# 3                            {}      38
# 4                            {}      40
#
# Using 'tag_text' as the tag identifier column
#
# ⚠ Warning: 103 location_tags have unmapped tags:
# Unmapped tags: ['family_friendly', 'quick_bite']
#
# Final location_tags shape: (6362, 5)
# Columns: ['location_id', 'tag_id', 'score', 'source', 'metadata']
#
# Sample rows:
#    location_id                                tag_id  score            source  \
# 0            1  d0ae158d-cedd-4f29-9c03-6ebfe2c0a76c   92.0  cuisine_detected
# 1            1  51eec92e-5a7d-4b2f-a96c-dc364b1b253a   75.0      google_types
# 2            2  51eec92e-5a7d-4b2f-a96c-dc364b1b253a   75.0      google_types
# 3            2  eaa9d86e-1f30-4198-b4c8-bed603ce5d3a   70.0     opening_hours
# 4            2  ec1bf490-469c-410c-97e7-6034a75ce9e2   65.0     opening_hours
#
#                                             metadata
# 0  {"original_tag": "italian", "tag_type": "CUISI...
# 1  {"original_tag": "restaurant", "tag_type": "CA...
# 2  {"original_tag": "restaurant", "tag_type": "CA...
# 3  {"original_tag": "open_late", "tag_type": "SCH...
# 4  {"original_tag": "sunday_open", "tag_type": "S...

# %%
# Save to CSV for Supabase upload
output_path = OUTPUT_DIR / "location_tags.csv"
location_tags_final.to_csv(output_path, index=False)
print(f"✓ Saved location_tags to: {output_path}")
print(f"  Total records: {len(location_tags_final):,}")
print(f"  Unique locations: {location_tags_final['location_id'].nunique():,}")
print(f"  Unique tags: {location_tags_final['tag_id'].nunique():,}")
# Out:
# ✓ Saved location_tags to: ../../output/pinit_notebook/location_tags.csv
#   Total records: 6,362
#   Unique locations: 1,608
#   Unique tags: 31

# %% [markdown]
# ## Optional: Upload location_tags directly to Supabase

# %%
# Uncomment to upload directly to Supabase (requires service key)
# WARNING: This will insert all location_tags into Supabase

UPLOAD_TO_SUPABASE = True  # Set to True to enable upload

if UPLOAD_TO_SUPABASE:
    # Convert to dict format for Supabase (without JSON string for metadata)
    location_tags_upload = location_tags_supabase[final_columns].copy()
    
    # Keep metadata as dict for proper JSONB storage
    records = location_tags_upload.to_dict('records')
    
    print(f"Uploading {len(records):,} location_tags to Supabase...")
    
    # Upload in batches (Supabase has limits on batch size)
    batch_size = 1000
    total_inserted = 0
    
    for i in range(0, len(records), batch_size):
        batch = records[i:i + batch_size]
        try:
            result = service.client.table("location_tags").insert(batch).execute()
            total_inserted += len(result.data)
            print(f"  Batch {i//batch_size + 1}: Inserted {len(result.data)} records")
        except Exception as e:
            print(f"  Batch {i//batch_size + 1}: Error - {e}")
            break
    
    print(f"\n✓ Total inserted: {total_inserted:,} location_tags")
else:
    print("Upload disabled. Set UPLOAD_TO_SUPABASE = True to upload.")
    print(f"CSV file ready for manual import: {output_path}")
# Out:
# Uploading 6,362 location_tags to Supabase...
#   Batch 1: Inserted 1000 records
#   Batch 2: Inserted 1000 records
#   Batch 3: Inserted 1000 records
#   Batch 4: Inserted 1000 records
#   Batch 5: Inserted 1000 records
#   Batch 6: Inserted 1000 records
#   Batch 7: Inserted 362 records
#
# ✓ Total inserted: 6,362 location_tags
